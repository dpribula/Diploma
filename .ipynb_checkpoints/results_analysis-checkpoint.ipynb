# %%
import pandas as pd
import evaluation_helper as eval
# %matplotlib inline
import matplotlib.pyplot as plt
# Read in data

predictions = pd.read_csv('/home/dave/projects/diploma/maps/nn_output/something2.csv', sep=';')
#features = pd.read_csv('../data/answer.csv', sep=';')

predictions.sample(5)
# Out:
#       id  prediction
# 157  157   84.775132
# 72    72   98.574948
# 173  173   91.454148
# 38    38   27.270558
# 104  104   86.688697

# %%
predictions = pd.read_csv('/home/dave/projects/diploma/maps/nn_output/something2.csv', sep=';')
y = predictions['prediction']
skip = 51
x = [x for x in range(skip, len(y))]
y = y[skip:]
color = ['red' if x==(159 - skip) else 'blue' for x in range(len(y))]
fig, ax = plt.subplots()
ax.set(ylabel='Average correctness', xlabel='Question Id')
ax.scatter(x, y,color=color)

# %%
predictions = pd.read_csv('/home/dave/projects/diploma/maps/nn_output/something2.csv', sep=';')
y = predictions['prediction']
skip = 51
x = [x for x in range(skip, len(y))]
y = y[skip:]
color = ['red' if x==(159 - skip) else 'blue' for x in range(len(y))]
fig, ax = plt.subplots()
ax.set(ylabel='Average correctness', xlabel='Question Id')
ax.scatter(x, y,color=color)

# %%
predictions = pd.read_csv('/home/dave/projects/diploma/maps/nn_output/something2.csv', sep=';')
y = predictions['prediction']
x = [x for x in range(len(y))]
color = ['red' if x==159 else 'blue' for x in range(len(y))]
fig, ax = plt.subplots()
ax.set(ylabel='Average correctness', xlabel='Question Id')
ax.scatter(x, y,color=color)
