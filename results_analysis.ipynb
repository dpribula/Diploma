# %%
import pandas as pd
import evaluation_helper as eval
# %matplotlib inline
import matplotlib.pyplot as plt
# Read in data

predictions = pd.read_csv('/home/dave/projects/diploma/maps/nn_output/something2.csv', sep=';')
#features = pd.read_csv('../data/answer.csv', sep=';')

predictions.sample(5)
# Out:
#       id  prediction
# 160  160   60.976630
# 216  216   69.995129
# 204  204   64.024812
# 215  215   51.615739
# 132  132   56.762850

# %%
predictions = pd.read_csv('/home/dave/projects/diploma/maps/nn_output/something2.csv', sep=';')
y = predictions['prediction']
skip = 51
country_id = 159
x = [x for x in range(skip, len(y))]
y = y[skip:]
color = ['red' if x==(country_id-skip) else 'blue' for x in range(len(y))]
# color[51-skip] = 'orange'
fig, ax = plt.subplots()
ax.set(ylabel='Average correctness', xlabel='Question Id')
ax.scatter(x, y,color=color)

# %%
predictions = pd.read_csv('/home/dave/projects/diploma/maps/nn_output/something2.csv', sep=';')
y = predictions['prediction']
skip = 51
country_id = 51
x = [x for x in range(skip, len(y))]
y = y[skip:]
color = ['red' if x==(country_id-skip) else 'blue' for x in range(len(y))]
# color[51-skip] = 'orange'
fig, ax = plt.subplots()
ax.set(ylabel='Average correctness', xlabel='Question Id')
ax.scatter(x, y,color=color)
